# %%
import pandas as pd
import plotly.express as px

# %%
centering_result = pd.read_csv("analysis/validation_analysis/result/centering.csv")

# %%
centering_result.head()
# Out:
#    Identifier  Centering  Centering_Ground_Truth
# 0  3727258206   9.728268                     9.0
# 1  3790347075   8.881133                     9.0
# 2  3829836084   8.710790                     9.0
# 3  3889981070   8.789421                     9.5
# 4  3769403002   9.365221                    10.0

# %%
centering_result['Diff'] = (centering_result['Centering'] - centering_result['Centering_Ground_Truth'])
fig = px.histogram(centering_result, x = 'Diff', title = 'Centering: Differences between prediction and ground-truth values')
fig.show()
# Out:
# <div>                            <div id="551b72bb-21e6-4895-9779-f8b86304ff78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("551b72bb-21e6-4895-9779-f8b86304ff78")) {                    Plotly.newPlot(                        "551b72bb-21e6-4895-9779-f8b86304ff78",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Diff=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[0.7282683849334717,-0.11886739730834961,-0.2892097234725952,-0.7105786800384521,-0.6347793340682983,-0.1989990472793579,0.30511999130249023,0.1332322359085083,0.20394301414489568,-0.35844993591308594,-0.5638355016
# ...

# %%
corners_result = pd.read_csv("analysis/validation_analysis/result/corners.csv")

# %%
corners_result.head()
# Out:
#    Identifier   Corners  Corners_Ground_Truth
# 0  3779755024  3.404867                   3.0
# 1  3790347036  7.573063                   7.0
# 2  3729526026  6.359639                   6.5
# 3  3750017066  9.086477                   9.5
# 4  3773489002  3.404867                   4.0

# %%
corners_result['Diff'] = (corners_result['Corners'] - corners_result['Corners_Ground_Truth'])
fig = px.histogram(corners_result, x = 'Diff', title = 'Corners: Differences between prediction and ground-truth values')
fig.show()
# Out:
# <div>                            <div id="4ac3caf3-d912-43bf-8440-2be0e208fdde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ac3caf3-d912-43bf-8440-2be0e208fdde")) {                    Plotly.newPlot(                        "4ac3caf3-d912-43bf-8440-2be0e208fdde",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Diff=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[0.40486675500869707,0.5730627775192261,-0.14036083221435547,-0.41352343559265137,-0.5951332449913029,0.6815080642700195,-0.6169021129608154,0.02941107749938965,0.02729165554046631,-0.5951332449913029,-0.1943868398
# ...

# %%
edges_result = pd.read_csv("analysis/validation_analysis/result/edges.csv")

# %%
edges_result.head()
# Out:
#    Identifier     Edges  Edges_Ground_Truth
# 0  3779755122  5.637629                 6.0
# 1  3761772047  4.274985                 4.5
# 2  3783187046  9.051152                 9.0
# 3  3757764123  5.296044                 5.5
# 4  3817031008  6.221293                 6.5

# %%
edges_result['Diff'] = (edges_result['Edges'] - edges_result['Edges_Ground_Truth']).abs()
fig = px.histogram(edges_result, x = 'Diff', title = 'Edges: Differences between prediction and ground-truth values')
fig.show()
# Out:
# <div>                            <div id="92c743b0-1365-4d36-b3d8-82441afc91a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92c743b0-1365-4d36-b3d8-82441afc91a7")) {                    Plotly.newPlot(                        "92c743b0-1365-4d36-b3d8-82441afc91a7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Diff=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[0.36237096786499023,0.22501540184020996,0.051152467727659356,0.20395565032958984,0.27870678901672363,0.08216989040374756,0.43138277530670166,0.27498459815979004,0.19051992893218994,0.10375058650970459,0.4449363946
# ...

# %%
surface_result = pd.read_csv("analysis/validation_analysis/result/surface.csv")

# %%
surface_result.head()
# Out:
#    Identifier   Surface  Surface_Ground_Truth
# 0  3834529061  2.298725                   1.0
# 1  3760202035  6.771133                   8.0
# 2  3877888008  8.100383                   9.0
# 3  3857203100  4.342918                   4.5
# 4  3852955009  6.503569                   7.0

# %%
surface_result['Diff'] = (surface_result['Surface'] - surface_result['Surface_Ground_Truth']).abs()
fig = px.histogram(surface_result, x = 'Diff', title = 'Surface: Differences between prediction and ground-truth values')
fig.show()
# Out:
# <div>                            <div id="f3da86cf-8f93-46a2-a8b2-90689ad62d05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3da86cf-8f93-46a2-a8b2-90689ad62d05")) {                    Plotly.newPlot(                        "f3da86cf-8f93-46a2-a8b2-90689ad62d05",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Diff=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[1.2987249493598938,1.2288670539855957,0.8996173143386841,0.15708190202713013,0.49643051624298096,1.7303799390792847,2.721717596054077,2.055785894393921,1.3857688307762146,0.6565845608711243,0.746947169303894,1.437
# ...
