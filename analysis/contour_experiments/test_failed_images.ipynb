# %%
import cv2
import json
import os
import matplotlib.pyplot as plt

# %%
with open(os.path.join("analysis", "contour_experiments", "failed_back.json"), 'r') as f:
    l = json.load(f)

# %%
image = cv2.imread(os.path.join("data", l[0], "back.jpg"))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
